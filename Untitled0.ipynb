# %%
import numpy as np
import pandas as pd

# %% [markdown]
# create a dataframe

# %%
df=pd.DataFrame(np.random.randn(10,4),columns=['A','B','C','D'])

# %%
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.128353  -0.244342  -0.108412  -0.175251
# std     1.098024   0.998226   0.951600   0.914239
# min    -1.647805  -2.610515  -1.500989  -2.048822
# 25%    -0.971062  -0.529208  -0.651755  -0.648074
# 50%    -0.109830  -0.109587   0.034851   0.111183
# 75%     0.289642   0.342616   0.353304   0.279746
# max     1.668643   0.925560   1.326458   0.885252

# %%
dt=np.array(["red","white","blue","yellow"])

# %%
st=pd.Series(dt)

# %%
st
# Out:
# 0       red
# 1     white
# 2      blue
# 3    yellow
# dtype: object

# %%
dt
# Out:
# array(['red', 'white', 'blue', 'yellow'], dtype='<U6')

# %%
 dt={'a':1,'aa':2,'b':3,'c':4}

# %%
s=pd.Series(dt)

# %%
s
# Out:
# a     1
# aa    2
# b     3
# c     4
# dtype: int64

# %%
print(s.aa)
# Out:
# 2

# %%
dt
# Out:
# {'a': 1, 'aa': 2, 'b': 3, 'c': 4}

# %%
s.values
# Out:
# array([1, 2, 3, 4])

# %%
s.index
# Out:
# Index(['a', 'aa', 'b', 'c'], dtype='object')

# %%
s[3]
# Out:
# 4

# %%
s[0]=5

# %%
s[0]
# Out:
# 5

# %% [markdown]
# create DATA FRAME

# %%
data={
        'colors' : ["red","blue","green","yellow"],
      'availability' : [0,11,21,31]}

# %%
data
# Out:
# {'colors': ['red', 'blue', 'green', 'yellow'], 'availability': [0, 11, 21, 31]}

# %%
stock=pd.DataFrame(data)

# %%
stock
# Out:
#    colors  availability
# 0     red             0
# 1    blue            11
# 2   green            21
# 3  yellow            31

# %%
stock=pd.DataFrame(data,index=[0,1,2,3])

# %%
stock
# Out:
#    colors  availability
# 0     red             0
# 1    blue            11
# 2   green            21
# 3  yellow            31

# %%
stock.loc[[3]]
# Out:
#    colors  availability
# 3  yellow            31

# %%
  stock.loc[2:,['availability']]
# Out:
#    availability
# 2            21
# 3            31

# %%
  stock.loc[:,['colors']]
# Out:
#    colors
# 0     red
# 1    blue
# 2   green
# 3  yellow

# %%
stock.iloc[:,0]
# Out:
# 0       red
# 1      blue
# 2     green
# 3    yellow
# Name: colors, dtype: object

# %%
stock.iloc[:,1]
# Out:
# 0     0
# 1    11
# 2    21
# 3    31
# Name: availability, dtype: int64

# %%
stock.iloc[:-3]
# Out:
#   colors  availability
# 0    red             0

# %%
stock.iloc[0:6]
# Out:
#    colors  availability
# 0     red             0
# 1    blue            11
# 2   green            21
# 3  yellow            31

# %% [markdown]
# MERGE THE DF

# %%
 item={'Item':["ball","book","pen","chair"],
       'Price':[10,20,30,40],
       'colors':["red","blue","green","yellow"]}

# %%
df=pd.DataFrame(item)

# %%
df
# Out:
#     Item  Price  colors
# 0   ball     10     red
# 1   book     20    blue
# 2    pen     30   green
# 3  chair     40  yellow

# %%
merge1=pd.merge(df,stock,on='colors')

# %%
merge1
# Out:
#     Item  Price  colors  availability
# 0   ball     10     red             0
# 1   book     20    blue            11
# 2    pen     30   green            21
# 3  chair     40  yellow            31

# %%
con=pd.concat([df,stock],axis=1)

# %%
con
# Out:
#     Item  Price  colors  colors  availability
# 0   ball     10     red     red             0
# 1   book     20    blue    blue            11
# 2    pen     30   green   green            21
# 3  chair     40  yellow  yellow            31

# %%
conr=pd.concat([df,stock],axis=0)

# %%
conr
# Out:
#     Item  Price  colors  availability
# 0   ball   10.0     red           NaN
# 1   book   20.0    blue           NaN
# 2    pen   30.0   green           NaN
# 3  chair   40.0  yellow           NaN
# 0    NaN    NaN     red           0.0
# 1    NaN    NaN    blue          11.0
# 2    NaN    NaN   green          21.0
# 3    NaN    NaN  yellow          31.0
